# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
geoapify_key = "410ea6284f21479a9e5b8a0ed2548cb5"

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity
# 0        0  port-aux-francais -49.3500   70.2167    278.66        96  \
# 1        1         constantia  44.1833   28.6500    293.54        76
# 2        2           becerril   9.7041  -73.2793    307.07        54
# 3        3            tuburan   6.6439  122.2736    299.48        87
# 4        4       arkhangel'sk  64.5401   40.5433    285.56        92
#
#    Cloudiness  Wind Speed Country        Date
# 0          98        9.26      TF  1686679480
# 1          67        5.17      RO  1686679211
# 2          81        2.41      CO  1686679481
# 3         100        1.36      PH  1686679481
# 4          94        2.78      RU  1686679481

# %%
import folium

# Create a map centered on a specific location
m = folium.Map(location=[0, 0], zoom_start=2)

# Add markers for each city
for _, row in city_data_df.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Lng']],
        popup=row['City'],
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ideal_conditions = {
    'Max Temp': (21, 27),  # Desired temperature range in Celsius
    'Wind Speed': 4.5,  # Desired maximum wind speed in m/s
    'Cloudiness': 0  # Desired maximum cloudiness percentage
}

filtered_df = city_data_df[
    (city_data_df['Max Temp'] > ideal_conditions['Max Temp'][0]) &
    (city_data_df['Max Temp'] < ideal_conditions['Max Temp'][1]) &
    (city_data_df['Wind Speed'] < ideal_conditions['Wind Speed']) &
    (city_data_df['Cloudiness'] <= ideal_conditions['Cloudiness'])
].copy()  # Make a copy of the filtered DataFrame

# Drop any rows with null values in the copied DataFrame
filtered_df.dropna(inplace=True)

# Display sample data
filtered_df.head()
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Set the base URL for the Geoapify API
base_url = "https://api.geoapify.com/v1/places/by-coordinates"

# Iterate over the rows of the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Retrieve the latitude and longitude for the current city
    lat = row['Lat']
    lng = row['Lng']
    
    # Set the API request parameters
    params = {
        "lat": lat,
        "lon": lng,
        "limit": 1,
        "type": "hotel",
        "radius": 10000,
        "apiKey": geoapify_key
    }
    
    # Send the API request
    response = requests.get(base_url, params=params).json()
    
    # Retrieve the hotel name and country from the API response
    if response["features"]:
        hotel_name = response["features"][0]["properties"]["name"]
        country = response["features"][0]["properties"]["country"]
    else:
        hotel_name = "Hotel not found"
        country = "N/A"
    
    # Update the hotel_df DataFrame with the hotel name and country
    hotel_df.at[index, "Hotel Name"] = hotel_name
    hotel_df.at[index, "Country"] = country

# Display the updated hotel_df DataFrame
hotel_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Humidity]
# Index: []

# %%
# Drop any rows with null values in the copied DataFrame
filtered_df.dropna(inplace=True)

# %%
# Display sample data
filtered_df.head()
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 0  port-aux-francais      TF -49.3500   70.2167        96
# 1         constantia      RO  44.1833   28.6500        76
# 2           becerril      CO   9.7041  -73.2793        54
# 3            tuburan      PH   6.6439  122.2736        87
# 4       arkhangel'sk      RU  64.5401   40.5433        92

# %%
# Create the hotel_df DataFrame with desired columns
hotel_df = filtered_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Display sample data
hotel_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Humidity]
# Index: []

# %%
# Set the base URL for the Geoapify API
base_url = "https://api.geoapify.com/v1/places/by-coordinates"

# Iterate over the rows of the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Retrieve the latitude and longitude for the current city
    lat = row['Lat']
    lng = row['Lng']
    
    # Set the API request parameters
    params = {
        "lat": lat,
        "lon": lng,
        "limit": 1,
        "type": "hotel",
        "radius": 10000,
        "apiKey": geoapify_key
    }
    
    # Send the API request
    response = requests.get(base_url, params=params).json()
    
    # Retrieve the hotel name and country from the API response
    if response["features"]:
        hotel_name = response["features"][0]["properties"]["name"]
        country = response["features"][0]["properties"]["country"]
    else:
        hotel_name = "Hotel not found"
        country = "N/A"
    
    # Update the hotel_df DataFrame with the hotel name and country
    hotel_df.at[index, "Hotel Name"] = hotel_name
    hotel_df.at[index, "Country"] = country

# Display the updated hotel_df DataFrame
hotel_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Humidity]
# Index: []

# %%
# Set the base URL for the Geoapify API
base_url = "https://api.geoapify.com/v1/places/by-coordinates"

# Iterate over the rows of the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Retrieve the latitude and longitude for the current city
    lat = row['Lat']
    lon = row['Lng']
    
    # Set the API request parameters
    params = {
        "lat": lat,
        "lon": lon,
        "limit": 1,
        "type": "hotel",
        "radius": 10000,
        "apiKey": geoapify_key
    }
    
    # Send the API request
    response = requests.get(base_url, params=params).json()
    
    # Check if any results are found
    if response["features"]:
        # Retrieve the hotel name and country from the API response
        hotel_name = response["features"][0]["properties"]["name"]
        country = response["features"][0]["properties"]["country"]
        
        # Update the hotel_df DataFrame with the hotel name and country
        hotel_df.at[index, "Hotel Name"] = hotel_name
        hotel_df.at[index, "Country"] = country
    else:
        # If no results are found, set the hotel name and country as "Not found"
        hotel_df.at[index, "Hotel Name"] = "Not found"
        hotel_df.at[index, "Country"] = "Not found"

# Display the updated hotel_df DataFrame
hotel_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Humidity]
# Index: []
